# %%
# 🔄 Install dependencies (if using Google Colab)
# !pip install google-generativeai tavily-python
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Collecting tavily-python
#   Downloading tavily_python-0.7.10-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.176.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.14.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from tavily-python) (2.32.3)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tavily-python) (0.9.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from tavily-python) (0.28.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->tavily-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->tavily-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->tavily-python) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->tavily-python) (2025.7.14)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.5.1->tavily-python) (2024.11.6)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->tavily-python) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->tavily-python) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->tavily-python) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.4.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->tavily-python) (1.3.1)
# Downloading tavily_python-0.7.10-py3-none-any.whl (15 kB)
# Installing collected packages: tavily-python
# Successfully installed tavily-python-0.7.10

# %%
import google.generativeai as genai
from tavily import TavilyClient
import json
from datetime import datetime

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1

# %%
from dotenv import load_dotenv
import os

# 🔄 Load custom .env file (not named .env by default)
load_dotenv(dotenv_path="API_Key.env")

# 🔐 Fetch keys
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")

# ✅ Check and display partial key
if not GEMINI_API_KEY:
    raise ValueError("❌ GEMINI_API_KEY not found in API_Key.env")

if not TAVILY_API_KEY:
    raise ValueError("❌ TAVILY_API_KEY not found in API_Key.env")

print("✅ Gemini API Key Loaded:", GEMINI_API_KEY[:5] + "*****")
print("✅ Tavily API Key Loaded:", TAVILY_API_KEY[:5] + "*****")
# Out:
# ✅ Gemini API Key Loaded: AIzaS*****
# ✅ Tavily API Key Loaded: tvly-*****

# %%
# 🔐 Authenticate with Google Generative AI
genai.configure(api_key=GEMINI_API_KEY)

# 🔐 Authenticate Tavily
tavily_client = TavilyClient(api_key=TAVILY_API_KEY)

# %%
# initilize the clinets - api module
model = genai.GenerativeModel('gemini-2.0-flash')

# %%
class TravelPlanningAssistant:
  def __init__(self):
    self.destination = ""
    self.duration = ""
    self.budget = ""
    self.interests = [] #array not a str
    self.travel_style = ""

  def get_travel_info(self):
    print(f"Welcome to Travel buddy...")
    print("="*60)

    self.destination = input("Where do you want to go? ").strip()
    self.duration = input("How many days? ").strip()
    self.budget = input("What's your budget range? (500-1000, midrange, luxury)").strip()

    print(f"\nWhat are you interested in? (seperate with commas)")
    print("Examples : food, culture, adventure, nature, shopping, history")
    interests_input = input("Interest: ").strip()
    self.interests = [interest.strip() for interest in interests_input.split(',') if interest.strip()]

    print("\nTravel Style")
    print(f"1. Backpacker/Budget")
    print(f"2. Comfort/Mid-range")
    print(f"3. Luxury")
    print(f"4. Adventure")
    print(f"5. Cultural/Historical")
    style_choice = input("Choose (1-5): ").strip()

    styles= {
        "1":"Backpacker/Budget",
        "2":"Comfort/Mid-range",
        "3":"Luxury",
        "4":"Adventure",
        "5":"Cultural/Historical"
    }

    self.travel_style = styles.get(style_choice,"mid-range")

  def research_desitination(self):
    print(f"\n Researching Destination {self.destination}...")

    research_queries = [
        f"{self.destination} travel guide 2025-2026",
        f"{self.destination} best attractions things to do",
        f"{self.destination} travel safety current situation",
        f"{self.destination} weather climate best time to visit",
        f"{self.destination} budget costs accomodation and food",
    ]

    all_research = {}

    for query in research_queries:
      try:
        print(f"Searching : {query}....")
        results = tavily_client.search(query=query, max_results=3)
        research_text = ""
        for result in results.get('results',[]):
          research_text += f"Sources : {result.get('title','Unknown')}\n"
          research_text += f"{result.get('content','No Content')}\n\n"
        all_research[query] = research_text
      except Exception as e:
        print(f"Error Searching : {query}: {str(e)}")
        all_research[query] = "No information available"
    return all_research

  def create_travel_plan(self, research_data):
    print(f"Creating your personalizd travel plan....")

    combined_research = ""
    for query, content in research_data.items():
      combined_research += f"=== {query} ===\n{content}\n\n"

    prompt = f"""
    You are an expert travel planner. Create a comprehensive and detailed travel plan based on:

    DESTINATION : {self.destination}
    DURATION: {self.duration}
    BUDGET:{self.budget}
    INTERESTS:{self.interests}
    TRAVEL_STYLE:{self.travel_style}

    RESEARCH DATA: {combined_research[:8000]}

    Create a detailed plan with:

    1.**DESTINATION OVERVIEW**
      -Brief description and highlights
      -Best time time to visit
      -Cultural tips and etiquette

    2.**SAFETY & PRACTICAL INFO**
      -Current safety situation
      -Visa Requirements
      -Currency exchange and payment method
      - Language Tips

    3. **DAILY ITENARY**
      -Day-by-day plan for {self.destination}
      -Mix of must-see attractions and personal interests
      -Include travel time between locations

    4.**FOOD AVAILABE**
      -Country specific cusisine information
      -Veg food vs Non-veg food based information for veg or vegal travellers

    5. **EMERGENCY CONTACT**
      -Imporatant phone numbers
      -Embassy/consulate info

    Make it practical, detailed, and personalized to their interests and budget
    """

    try:
      response = model.generate_content(prompt)
      return response.text
    except Exception as e:
      print(f"Error creating travel plan : {str(e)}")

  def get_current_alerts(self):
    print(f"Checking current travel alerts... Travel advisory")
    try:
      alert_query = f"{self.destination} travel advisory warning alert 2025 2026"
      result = tavily_client.search(query=alert_query, max_results=3)

      alerts = ""
      for result in results.get('results',[]):
        alerts += f"⚠️ {result.get('title','Unknown')}\n"
        alerts += f"⚠️ {result.get('content','No Content')[:200]}\n\n"
      return alerts if alerts else "No current travel alerts found!!"
    except Exception as e:
      return f"Eroor checking alerts: {e}"

  def run(self):
    try:
      self.get_travel_info()
      research_data = self.research_desitination()
      alerts = self.get_current_alerts()

      travel_plan = self.create_travel_plan(research_data)

      print("\n" + "="*60)
      print(f"Your personalized travel plan is.....")
      print("="*60)
      print(travel_plan)

      print("\n" + "="*60)
      print(f"Current travel alerts.....")
      print("="*60)
      print(alerts)

      print("\n" + "="*60)
      print(f"Travel Summary ")
      print(f"Destination : {self.destination}")
      print(f"Duration : {self.duration}")
      print(f"Budget : {self.budget}")
      print(f"Interests : {self.interests}")
      print(f"Style : {self.travel_style}")

      save = input("\n Save this plan to file? (y/n): ").strip().lower()
      if save == 'y':
            filename = f"{travel_plan_my_file}.txt"
            with open(filename, 'w', encoding='utf-8') as f:
                f.write(f"Travel plan")
                f.write(travel_plan)
                f.write(alerts)
            print(f"Plan saved")
    except Exception as e:
            pass

# %%
def main():
  assistant = TravelPlanningAssistant()

  while True:
    try:
      assistant.run()

      another = input("\n Plan another trip (y/n) : ").strip().lower()
      if another != 'y':
        print(f"Happy travels!")
        break
      assistant = TravelPlanningAssistant()
    except Exception as e:
      print(f"Goodbye")
      break

if __name__ == "__main__":
  main()
# Out:
# Welcome to Travel buddy...
# ============================================================
# Where do you want to go? delhi
# How many days? 5
# What's your budget range? (500-1000, midrange, luxury)5000
#
# What are you interested in? (seperate with commas)
# Examples : food, culture, adventure, nature, shopping, history
# Interest: food
#
# Travel Style
# 1. Backpacker/Budget
# 2. Comfort/Mid-range
# 3. Luxury
# 4. Adventure
# 5. Cultural/Historical
# Choose (1-5): 3
#
#  Researching Destination delhi...
# Searching : delhi travel guide 2025-2026....
# Searching : delhi best attractions things to do....
# Searching : delhi travel safety current situation....
# Searching : delhi weather climate best time to visit....
# Searching : delhi budget costs accomodation and food....
# Checking current travel alerts... Travel advisory
# Creating your personalizd travel plan....
#
# ============================================================
# Your personalized travel plan is.....
# ============================================================
# Okay, here is a detailed luxury travel plan for 5 days in Delhi, tailored to a food lover with a budget of ₹5000 (approximately $60 USD). Please note that achieving a "luxury" experience on this budget will require creative planning and prioritizing what truly defines luxury for you (e.g., exclusive experiences, high-quality ingredients, unique locations) over opulent accommodations. This itinerary focuses on maximizing the food experience while keeping costs manageable.
#
# **1. DESTINATION OVERVIEW: Delhi**
#
# *   **Brief Description & Highlights:** Delhi is a city of layered history, bustling markets, and incredible culinary diversity. It's where ancient empires meet modern India, offering a vibrant and sometimes overwhelming sensory experience. Key highlights include historical monuments like the Red Fort, Humayun's Tomb, and Qutub Minar; spiritual sites like Akshardham Temple and Lotus Temple; and, most importantly for you, a world-class food scene.
# *   **Best Time to Visit:** October to March is ideal. The weather is pleasant, with mild days and cool evenings, perfect for exploring the city. July can be hot and humid.
# *   **Cultural Tips & Etiquette:**
#     *   **Dress modestly,** especially when visiting religious sites. Cover your shoulders and knees.
#     *   **Remove your shoes** before entering temples and some homes.
#     *   **Use your right hand** for eating and giving/receiving items.
#     *   **Bargaining is expected** in markets but be respectful.
#     *   **Be mindful of personal space,** but expect crowds and close proximity to others.
#     *   **"Namaste" or "Namaskar"** (with folded hands) is a respectful greeting.
#
# **2. SAFETY & PRACTICAL INFO**
#
# *   **Current Safety Situation:** Exercise increased caution in Delhi due to petty crime and the potential for terrorism (though the risk is relatively low). Be aware of your surroundings, especially in crowded areas. Avoid sharing personal information with strangers. Keep valuables secure.
# *   **Visa Requirements:** Most nationalities require a visa to enter India. Apply for an e-Visa online well in advance of your trip (check the official Indian government website for e-Visa details).
# *   **Currency Exchange and Payment Methods:** The currency is the Indian Rupee (INR).
#     *   **Exchange:** Exchange currency at the airport or authorized money changers. Avoid street vendors.
#     *   **Payment:** Credit cards are accepted in larger establishments (hotels, restaurants), but cash is essential for markets, street food, and smaller shops. ATMs are widely available.
# *   **Language Tips:** Hindi and English are widely spoken. Learning a few basic Hindi phrases will be appreciated:
#     *   Namaste (Hello/Goodbye)
#     *   Shukriya (Thank you)
#     *   Kitna hai? (How much?)
#     *   Theek hai (Okay)
#
# **3. DAILY ITINERARY (Luxury Food Focus, Budget-Conscious)**
#
# *   **Important Notes:**
#     *   **Transportation:** Utilize Delhi's efficient metro system and ride-sharing apps (Ola, Uber) to save money and time. Auto-rickshaws are also available but negotiate the fare beforehand.
#     *   **Accommodation:** Choose a well-reviewed guesthouse or budget hotel in a central location like Paharganj or Karol Bagh to save money and make sure you are able to travel places with ease.
#     *   **Luxury Defined:**  On this budget, "luxury" will mean prioritizing high-quality ingredients, unique culinary experiences, and smaller, more authentic establishments over lavish decor or Michelin-starred restaurants.
#     *   **Budget Breakdown:**  I'm assuming an average of ₹1000 per day for food and activities, and the rest for accommodation and transport. This requires careful planning and sticking to street food and local eateries where possible.
#
#     **Day 1: Old Delhi Food Walk & Spice Market Exploration**
#
#     *   **Morning (9:00 AM):** Arrive at Indira Gandhi International Airport (DEL). Take the Airport Express Metro Line to New Delhi Metro Station (allow 45 mins-1 hour).
#     *   **Morning (10:30 AM):** Check into your guesthouse/hotel. Leave your luggage.
#     *   **Late Morning (11:30 AM):** Head to Old Delhi (Chandni Chowk) via metro (Yellow Line to Chandni Chowk station).
#     *   **Lunch (12:30 PM - 3:00 PM):**  *Old Delhi Food Walk:* Immerse yourself in the legendary street food scene.
#         *   **Karim's:** Famous for its Mughlai cuisine, try the mutton burra and nihari. (₹300-₹500).
#     *   **Evening (7:00 PM - 9:00 PM):** Dinner at a restaurant of your choice, reflecting on your culinary journey through Delhi. (₹400-₹600)
#
#     **Day 5: Last Bites & Departure**
#
#     *   **Morning (9:00 AM):** Enjoy a leisurely breakfast at your accommodation or a local cafe (₹100-₹200).
#     *   **Morning (10:00 AM - 12:00 PM):**  Last-minute souvenir shopping or revisit your favorite food stall.
#     *   **Lunch (12:30 PM - 2:00 PM):**  Enjoy a final Indian meal before heading to the airport. (₹300-₹500)
#     *   **Afternoon (2:00 PM):**  Check out of your accommodation.
#     *   **Afternoon (3:00 PM):**  Travel to Indira Gandhi International Airport (DEL) via Airport Express Metro.
#     *   **Evening:** Depart from Delhi.
#
# **4. FOOD AVAILABLE**
#
# *   **Indian Cuisine Overview:** Indian cuisine is incredibly diverse, varying greatly from region to region. Delhi is a melting pot of culinary influences, offering Mughlai, North Indian, South Indian, and street food delights.
# *   **Vegetarian vs. Non-Vegetarian:** India has a large vegetarian population.  Finding vegetarian food is extremely easy. Many restaurants offer separate vegetarian and non-vegetarian sections in their menus and kitchens. Delhi has fantastic vegetarian options, including:
#     *   **Parathas:** Stuffed flatbreads with various fillings (potato, cauliflower, paneer).
#     *   **Chhole Bhature:** Chickpea curry served with fried bread.
#     *   **Dosa/Idli/Vada:** South Indian specialties made from fermented lentil and rice batter.
#     *   **Paneer Tikka:** Grilled cubes of Indian cheese marinated in spices.
#     *   **Dal Makhani:** Creamy lentil dish.
#     *   **Vegetable Biryani:** Rice dish cooked with vegetables and spices.
# *   **For Vegans:**  While dairy is common, vegan options are becoming more available, especially in modern cafes. Look for dishes made with coconut milk or tofu instead of dairy.
#
# **5. EMERGENCY CONTACTS**
#
# *   **Police:** 100
# *   **Ambulance:** 102
# *   **Fire:** 101
# *   **Women's Helpline:** 1091
# *   **Emergency Number:** 112
# *   **U.S. Embassy in New Delhi:**
#     *   Address: Shantipath, Chanakyapuri, New Delhi - 110021
#     *   Phone: +91-11-2419-8000
#     *   Website: [Use Google to search for the official U.S. Embassy in India website - provide current year link]
# *   **(Replace with the Embassy/Consulate of your Nationality):**  [Search online for the contact details of your country's embassy or consulate in Delhi.]
#
# **Important Considerations for Luxury on a Budget:**
#
# *   **Prioritize Experiences:** Focus your spending on unique culinary experiences like cooking classes or private food tours, even if it means sacrificing on accommodation.
# *   **Seek Out Hidden Gems:** Ask locals for recommendations for smaller, family-run restaurants that offer authentic and delicious food at lower prices.
# *   **Negotiate Respectfully:** When bargaining in markets or with auto-rickshaw drivers, always be polite and respectful. A little negotiation can go a long way.
# *   **Hydration:** Buy bottled water from reputable sources to avoid getting sick.
# *   **Travel Insurance:** Purchase travel insurance to cover any unexpected medical expenses or travel disruptions.
#
# Enjoy your culinary adventure in Delhi! Remember to be open to new experiences, embrace the chaos, and savor every delicious bite!
#
#
# ============================================================
# Current travel alerts.....
# ============================================================
# Eroor checking alerts: name 'results' is not defined
#
# ============================================================
# Travel Summary
# Destination : delhi
# Duration : 5
# Budget : 5000
# Interests : ['food']
# Style : Luxury
#
#  Save this plan to file? (y/n): n
#
#  Plan another trip (y/n) : n
# Happy travels!
